# %%
import os
import os.path
import shutil
import sys
import glob
from os import remove
from shutil import rmtree

import pandas as pd # cargamos la libreria pandas

# %%
source = '/home/infinity/Documentos/Carpeta sin título'
destination = '/home/infinity/Documentos/Carpeta sin título/practica'
carpt = 0

# %%
while not os.path.exists(source):
    source = input('Enter a valid source directory\n')
while not os.path.exists(destination):
    destination = input('Enter a valid destination directory\n')

# %%
source =  source
print(source)
print(destination)
# Out:
# /home/infinity/Documentos/Carpeta sin título
# /home/infinity/Documentos/Carpeta sin título/practica

# %%
for f in glob.glob("*EX*.xlsx"):
    print(f)

# %% [markdown]
# ## read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)

# %%
carpt = 0
for root, dirs, files in os.walk(source, topdown=False):
    for file in files: 
        extension = os.path.splitext(file)[0][0:5].upper()
        #print(file) 
        if extension == "MP_EX":
            print(file)
            df = pd.read_excel(os.path.join(root,file), sheet_name='TANQUE', index_col=6, usecols="A:P" )
            print(df.shape)
           # ruta = '"'+ os.path.join(root,file).upper()+ '"'
           
            #print(os.path.join(root,file))
            #df = pd.read_csv(ruta, decimal='.', encoding='utf-8', header=0)
            #df.shape
            carpt +=   1
        
        
    #rmtree(os.path.join(root))
    
print("PROCESO TERMINADO..OK  TOTAL CARPETAS: " + str(carpt ) )
# Out:
# MP_EX_31012_Universidad Ideas_4628178.xlsx
# (98, 15)
# MP_EX_Santa_ana_Oriental_4628645.xlsx
# (98, 15)
# MP_EX_MULTIPLAZA INDOOR.xlsx
# (98, 15)
# MP_EX_Estacion 11076 - EDIFICIO ARGOS_4628791.xlsx
# (98, 15)
# MP_EX_CENTRO INDUSTRIAL BOGOTA_4626638.xlsx
# (98, 15)
# MP_EX_LA CALERA_4626940.xlsx
# (100, 15)
# MP_EX_FLORENCIA_BOGOTÁ_4628401.xlsx
# (98, 15)
# MP_EX_LA CABRERA_4627807.xlsx
# (98, 15)
# MP_EX_UGI BOGOTA_4627207.xlsx
# (98, 15)
# PROCESO TERMINADO..OK  TOTAL CARPETAS: 9

# %%
print(df.head(9))
print("Column headings:")
print(df.columns[0:10])
# Out:
#     FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA           Unnamed: 1  \
# NaN  Gerencia Operaciones Campo /Jefatura Operación...                   NaN
# NaN                          Código: RED-FT-0104020106                   NaN
# NaN                              PLAN DE MANTENIMIENTO                   NaN
# NaN                                            TANQUES                   NaN
# NaN              SISTEMA DE ALMACENAMIENTO COMBUSTIBLE                   NaN
# NaN                                                NaN                   NaN
# NaN                                     PERIODICIDAD:                    NaN
# NaN                                             FECHA:   2019-04-15 00:00:00
# NaN                                                NaN                   NaN
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 7 Unnamed: 8  \
# NaN        NaN        NaN        NaN        NaN           NaN        NaN
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA    True
# Unnamed: 1                                             True
# Unnamed: 2                                             True
# Unnamed: 3                                             True
# Unnamed: 4                                             True
#                                                        ...
# Unnamed: 16378                                         True
# Unnamed: 16379                                         True
# Unnamed: 16380                                         True
# Unnamed: 16381                                         True
# Unnamed: 16382                                         True
# Length: 16383, dtype: bool

# %%
df.isnull().sum()
# Out:
# FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA    58
# Unnamed: 1                                             91
# Unnamed: 2                                             95
# Unnamed: 3                                             94
# Unnamed: 4                                             92
#                                                        ..
# Unnamed: 16378                                         95
# Unnamed: 16379                                         96
# Unnamed: 16380                                         97
# Unnamed: 16381                                         97
# Unnamed: 16382                                         97
# Length: 16383, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1605396

# %%
nan_rows = df[df.isnull().any(1)]

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
print(df[df.isnull().any(axis=1)][null_columns].head(50))
# Out:
#                  FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA  \
# NaN               Gerencia Operaciones Campo /Jefatura Operación...
# NaN                                       Código: RED-FT-0104020106
# NaN                                           PLAN DE MANTENIMIENTO
# NaN                                                         TANQUES
# NaN                           SISTEMA DE ALMACENAMIENTO COMBUSTIBLE
# NaN                                                             NaN
# NaN                                                  PERIODICIDAD:
# NaN                                                          FECHA:
# NaN                                                             NaN
# NaN                                                  DATOS TECNICOS
# DIMENSIONES (cm)                                      MODELO TANQUE
# Diámetro                                                        NaN
# NaN                                                          Subase
# ...

# %%
df[10:18]
# Out:
#    FORMATO MANTENIMIENTO PREVENTIVO EQUIPOS DE ENERGIA  Unnamed: 1  \
# 10                                      MODELO TANQUE    CANT ACPM
# 11                                                NaN   Cap\n(Gls)
# 12                                             Subase          NaN
# 13                                          Reserva 1           45
# 14                                          Reserva 2          NaN
# 15                                          Reserva 3           80
# 16                                              TOTAL          125
# 17                                       INTERVENCION          NaN
#
#        Unnamed: 2      Unnamed: 3      Unnamed: 4 Unnamed: 5  \
# 10            NaN            TIPO             NaN        NaN
# 11  Existe\n(Gal)  Cilindro Vert.  Cilindro Hori.     Cúbico
# 12            NaN             NaN             NaN        NaN
# 13            NaN             NaN             NaN        NaN
# ...
