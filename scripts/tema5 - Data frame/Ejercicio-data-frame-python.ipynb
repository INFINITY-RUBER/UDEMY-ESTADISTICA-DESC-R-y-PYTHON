# %% [markdown]
# ## Preguntas de esta tarea

# %% [markdown]
# Carga el CSV de la carpeta de datos del tema llamado run.csv y responde a las siguientes preguntas.
#
# **1 - Indica cuantos estudiantes formaron parte del estudio de deporte**
#
# **2 - Indica cuantos individuos son hombres y cuantos son mujeres**
#
# **3 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?**
#
# **4 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio  para los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres. ¿Observas mucha diferencia?**
#
# **5 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores. ¿Observas mucha diferencia?**
#
# **6 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?**

# %%
import pandas as pd # cargamos la libreria pandas

# %%
df = pd.read_csv("../../data/run.csv", decimal='.', encoding='utf-8', header=0)

# %%
df = df.rename(columns={df.columns[0]: 'id'})

# %%
df
# Out:
#     id  pulso.antes  pulso.despues hace.deporte fuma genero  altura  peso  \
# 0    1           48             54           no   si      H    68.0   150
# 1    2           54             56           no   si      H    69.0   145
# 2    3           54             50           no   no      H    69.0   160
# 3    4           58             70           si   no      H    72.0   145
# 4    5           58             58           no   no      H    66.0   135
# ..  ..          ...            ...          ...  ...    ...     ...   ...
# 87  88           92             94           no   si      H    69.0   150
# 88  89           94             92           no   si      M    62.0   131
# 89  90           96            140           si   no      M    61.0   140
# 90  91           96            116           si   no      M    68.0   116
# 91  92          100            115           si   si      M    63.0   121
#
#    tipo.actividad
# 0            nula
# 1        moderada
# 2        moderada
# 3        moderada
# 4         intensa
# ..            ...
# 87       moderada
# 88       moderada
# 89       moderada
# 90       moderada
# 91       moderada
#
# [92 rows x 9 columns]

# %% [markdown]
# **1 - Indica cuantos estudiantes formaron parte del estudio de deporte**

# %%
df.shape
# Out:
# (92, 9)

# %% [markdown]
# **2 - Indica cuantos individuos son hombres y cuantos son mujeres**

# %%
generos = df[['id', 'genero']].groupby('genero').count()

# %%
generos.rename(columns={df.columns[0]: 'Total'})
# Out:
#         Total
# genero
# H          57
# M          35

# %% [markdown]
# **3 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?**

# %%
Df2 = df[['hace.deporte','pulso.antes','pulso.despues']]

# %%
Df2.groupby('hace.deporte').mean()
# Out:
#               pulso.antes  pulso.despues
# hace.deporte
# no              72.421053      72.315789
# si              73.600000      92.514286

# %% [markdown]
# **4 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio  para los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres. ¿Observas mucha diferencia?**

# %%
hace_deporte = df[df['hace.deporte'] == 'si'] 
hace_deporte.head()
# Out:
#     id  pulso.antes  pulso.despues hace.deporte fuma genero  altura  peso  \
# 3    4           58             70           si   no      H    72.0   145
# 6    7           60             76           si   no      H    71.0   170
# 11  12           62             76           si   si      H    73.5   160
# 12  13           62             75           si   no      H    72.0   195
# 13  14           62             58           si   no      H    72.0   175
#
#    tipo.actividad
# 3        moderada
# 6         intensa
# 11        intensa
# 12       moderada
# 13        intensa

# %%
hace_deporteDf2 = hace_deporte[['genero','pulso.antes','pulso.despues']]
hace_deporteDf2.head()
# Out:
#    genero  pulso.antes  pulso.despues
# 3       H           58             70
# 6       H           60             76
# 11      H           62             76
# 12      H           62             75
# 13      H           62             58

# %%
hace_deporteDf2.groupby('genero').mean()
# Out:
#         pulso.antes  pulso.despues
# genero
# H         70.250000      83.208333
# M         80.909091     112.818182

# %% [markdown]
# **5 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores. ¿Observas mucha diferencia?**

# %%
df.head()
# Out:
#    id  pulso.antes  pulso.despues hace.deporte fuma genero  altura  peso  \
# 0   1           48             54           no   si      H    68.0   150
# 1   2           54             56           no   si      H    69.0   145
# 2   3           54             50           no   no      H    69.0   160
# 3   4           58             70           si   no      H    72.0   145
# 4   5           58             58           no   no      H    66.0   135
#
#   tipo.actividad
# 0           nula
# 1       moderada
# 2       moderada
# 3       moderada
# 4        intensa

# %%
No_hace_deporte = df[df['hace.deporte'] == 'no'] 
No_hace_deporte.head()
# Out:
#    id  pulso.antes  pulso.despues hace.deporte fuma genero  altura  peso  \
# 0   1           48             54           no   si      H    68.0   150
# 1   2           54             56           no   si      H    69.0   145
# 2   3           54             50           no   no      H    69.0   160
# 4   5           58             58           no   no      H    66.0   135
# 5   6           58             56           no   no      M    67.0   125
#
#   tipo.actividad
# 0           nula
# 1       moderada
# 2       moderada
# 4        intensa
# 5       moderada

# %%
fumado_df  = No_hace_deporte[['fuma','pulso.antes','pulso.despues']]
fumado_df.groupby('fuma').mean()
# Out:
#       pulso.antes  pulso.despues
# fuma
# no      71.707317      71.512195
# si      74.250000      74.375000

# %% [markdown]
# **6 - Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?**

# %%
Estudiantes_Df = df[['tipo.actividad','pulso.antes','pulso.despues']]
Estudiantes_Df.groupby('tipo.actividad').mean()
# Out:
#                 pulso.antes  pulso.despues
# tipo.actividad
# intensa           71.571429      72.190476
# moderada          72.737705      82.786885
# nula              48.000000      54.000000
# suave             79.555556      82.222222
