# %% [markdown]
# # Data Frames

# %%
import pandas as pd # cargamos la libreria pandas

# %%
df = pd.read_csv("../../data/bodyfat.txt", delimiter=" ", decimal=".", encoding="utf-8")

# %%
df
# Out:
#      Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 1     1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 2     1.0853   6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3     1.0414  25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4     1.0751  10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 5     1.0340  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# ..       ...   ...  ...     ...     ...   ...    ...      ...    ...    ...
# 248   1.0736  11.0   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6
# 249   1.0236  33.6   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6
# 250   1.0328  29.3   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3
# 251   1.0399  26.0   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0
# 252   1.0271  31.9   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3
#
#      Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
df.head(8) # primeros 8
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 2   1.0853   6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3   1.0414  25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4   1.0751  10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 5   1.0340  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 6   1.0502  20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 7   1.0549  19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 8   1.0704  12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1
# 2  37.3   23.4    30.5     28.9   18.2
# 3  38.9   24.0    28.8     25.2   16.6
# 4  37.3   22.8    32.4     29.4   18.2
# 5  42.2   24.0    32.2     27.7   17.7
# 6  42.0   25.6    35.7     30.6   18.8
# ...

# %%
df.tail(8) # la cola
# Out:
#      Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 245   1.0334  29.0   67  199.50   68.50  40.7  118.3    106.1  101.6   58.2
# 246   1.0641  15.2   68  155.50   69.25  36.3   97.4     84.3   94.4   54.3
# 247   1.0308  30.2   69  215.50   70.50  40.8  113.7    107.6  110.0   63.3
# 248   1.0736  11.0   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6
# 249   1.0236  33.6   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6
# 250   1.0328  29.3   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3
# 251   1.0399  26.0   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0
# 252   1.0271  31.9   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3
#
#      Knee  Ankle  Biceps  Forearm  Wrist
# 245  38.8   24.1    32.1     29.3   18.5
# 246  37.5   22.6    29.2     27.3   18.5
# 247  44.0   22.6    37.5     32.6   18.8
# 248  34.8   21.5    25.6     25.7   18.5
# 249  40.8   23.2    35.2     28.6   20.1
# ...

# %%
df.loc[[1]] # si queremos un posicion, y la posicion primera es la 1  no el cero
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2  94.5   59.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1

# %%
df.loc[[5]]
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 5    1.034  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 5  42.2   24.0    32.2     27.7   17.7

# %%
df.iloc[[0]] # aceder por el indixe 1
df.iloc[[1]] # aceder por el indixe 2
# Out:
#    Density  Fat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  Knee  \
# 2   1.0853  6.1   22  173.25   72.25  38.5   93.6     83.0  98.7   58.7  37.3
#
#    Ankle  Biceps  Forearm  Wrist
# 2   23.4    30.5     28.9   18.2

# %%
df.iloc[[5]] # aceder por a la fila 6
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 6   1.0502  20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 6  42.0   25.6    35.7     30.6   18.8

# %%
df[12:20] # haceder a un rango de pocisiones 13 a 20
# Out:
#     Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 13   1.0513  20.8   32  180.50   69.50  38.4  102.0     91.6  103.9   63.4
# 14   1.0505  21.2   30  205.25   71.25  39.4  104.1    101.8  108.6   66.0
# 15   1.0484  22.1   35  187.75   69.50  40.5  101.3     96.4  100.1   69.0
# 16   1.0512  20.9   35  162.75   66.00  36.4   99.1     92.8   99.2   63.1
# 17   1.0333  29.0   34  195.75   71.00  38.9  101.9     96.4  105.2   64.8
# 18   1.0468  22.9   32  209.25   71.00  42.1  107.6     97.5  107.0   66.9
# 19   1.0622  16.0   28  183.75   67.75  38.0  106.8     89.6  102.4   64.2
# 20   1.0610  16.5   33  211.75   73.50  40.0  106.2    100.5  109.0   65.8
#
#     Knee  Ankle  Biceps  Forearm  Wrist
# 13  38.3   21.5    32.5     28.6   17.7
# 14  41.5   23.7    36.9     31.6   18.8
# 15  39.0   23.1    36.1     30.5   18.2
# 16  38.7   21.7    31.1     26.4   16.9
# 17  40.8   23.1    36.2     30.8   17.3
# 18  40.0   24.4    38.2     31.6   19.3
# ...

# %%
df[10:95:5]# tomar rangos con salgos de 5 en 5
# Out:
#     Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 11   1.0830   7.1   26  186.25   74.50  38.5  101.5     83.6   98.2   59.7
# 16   1.0512  20.9   35  162.75   66.00  36.4   99.1     92.8   99.2   63.1
# 21   1.0551  19.1   28  179.00   68.00  39.1  103.3     95.9  104.9   63.5
# 26   1.0911   3.7   27  159.25   71.50  35.7   89.6     79.7   96.5   55.0
# 31   1.0716  11.9   32  182.00   73.75  38.7  100.5     88.7   99.8   57.5
# 36   1.0101  40.1   49  191.75   65.00  38.4  118.5    113.1  113.8   61.9
# 41   1.0217  34.5   45  262.75   68.75  43.2  128.3    126.2  125.6   72.5
# 46   1.0670  13.9   43  164.25   73.25  35.7   96.6     81.5   97.2   58.4
# 51   1.0756  10.2   47  158.25   72.25  34.9   90.2     86.7   98.3   52.6
# 56   1.0473  22.6   54  198.00   72.00  39.9  107.6    100.0   99.6   57.2
# 61   1.0396  26.1   62  216.00   73.25  41.4  112.3    104.8  103.1   61.6
# ...

# %%
df.Density # con el punto (.) te vota las columnas
# Out:
# 1      1.0708
# 2      1.0853
# 3      1.0414
# 4      1.0751
# 5      1.0340
#         ...
# 248    1.0736
# 249    1.0236
# 250    1.0328
# 251    1.0399
# 252    1.0271
# Name: Density, Length: 252, dtype: float64

# %%
df.Density.sum() # columna Density y la suma
# Out:
# 266.0046

# %%
df.Density.mean() # columna Density y la media
# Out:
# 1.055573809523809

# %%
df.Density.median()# columna Density y la mediana  el del medio
# Out:
# 1.0549

# %%
df.Density.describe() # columna Density hace un resumen estadistico de la columna
# Out:
# count    252.000000
# mean       1.055574
# std        0.019031
# min        0.995000
# 25%        1.041400
# 50%        1.054900
# 75%        1.070400
# max        1.108900
# Name: Density, dtype: float64

# %%
df.describe() # hace un resumen estadistico de todo el data frame
# Out:
#           Density         Fat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
df.describe().transpose() # transponer el data frame resumido y se lee mucho mejor
# Out:
#          count        mean        std      min       25%       50%       75%  \
# Density  252.0    1.055574   0.019031    0.995    1.0414    1.0549    1.0704
# Fat      252.0   19.150794   8.368740    0.000   12.4750   19.2000   25.3000
# Age      252.0   44.884921  12.602040   22.000   35.7500   43.0000   54.0000
# Weight   252.0  178.924405  29.389160  118.500  159.0000  176.5000  197.0000
# Height   252.0   70.148810   3.662856   29.500   68.2500   70.0000   72.2500
# Neck     252.0   37.992063   2.430913   31.100   36.4000   38.0000   39.4250
# Chest    252.0  100.824206   8.430476   79.300   94.3500   99.6500  105.3750
# Abdomen  252.0   92.555952  10.783077   69.400   84.5750   90.9500   99.3250
# Hip      252.0   99.904762   7.164058   85.000   95.5000   99.3000  103.5250
# Thigh    252.0   59.405952   5.249952   47.200   56.0000   59.0000   62.3500
# Knee     252.0   38.590476   2.411805   33.000   36.9750   38.5000   39.9250
# ...

# %%
df.shape # el tamaño de Data frame (filas x columnas)
# Out:
# (252, 15)

# %%
df2 = pd.read_csv("http://winterolympicsmedals.com/medals.csv") # cargar desde la web

# %%
df2.shape # el tamaño de Data framen (filas x columnas)
# Out:
# (2311, 8)

# %%
df2.head() # en encabezado del dataframe
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
pd.read_table("http://winterolympicsmedals.com/medals.csv", delimiter=",") 
# la funcion predefinida es el read_table
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %% [markdown]
# # Cómo crear un data frame

# %%
import numpy as np # cargamos la libreria analices numerico y matematica de python

# %%
df = pd.DataFrame({
    'A': np.random.rand(10),
    'B': np.random.rand(10),
    'C': np.random.rand(10)
})

# %%
df
# Out:
#           A         B         C
# 0  0.219427  0.301711  0.111788
# 1  0.035688  0.705052  0.869580
# 2  0.504966  0.850482  0.625552
# 3  0.250936  0.672003  0.210007
# 4  0.620560  0.000157  0.453542
# 5  0.741306  0.771758  0.806686
# 6  0.111380  0.081290  0.222741
# 7  0.243909  0.938742  0.267362
# 8  0.205478  0.962710  0.292443
# 9  0.948222  0.831362  0.148417

# %%
df.mean() # media
# Out:
# A    0.388187
# B    0.611527
# C    0.400812
# dtype: float64

# %%
df.mean(axis='columns') # media por columnas
# Out:
# 0    0.210975
# 1    0.536773
# 2    0.660333
# 3    0.377649
# 4    0.358086
# 5    0.773250
# 6    0.138470
# 7    0.483338
# 8    0.486877
# 9    0.642667
# dtype: float64

# %%
df2 = pd.DataFrame({
    'key' : ['A', 'B', 'C', 'A', 'B', 'C'],
    'values' : range(6)
},
columns = ['key', 'values']
)
df2 # crear un data frame con dicionarios manualmente
# Out:
#   key  values
# 0   A       0
# 1   B       1
# 2   C       2
# 3   A       3
# 4   B       4
# 5   C       5

# %% [markdown]
# ## agregados para operaciones

# %%
df2.groupby('key')# agrupar por el mismo clave.  es un objeto

# %%
df2.groupby('key').mean() # agrupar por clave y saca la media aritmetica
# Out:
#      values
# key
# A       1.5
# B       2.5
# C       3.5

# %%
df2.groupby('key').median() # agrupar por clave y saca la mediana
# Out:
#      values
# key
# A       1.5
# B       2.5
# C       3.5

# %% [markdown]
# # Manipulación de data frames

# %%
df = pd.DataFrame({
       'key' : ['A', 'B', 'C', 'A', 'B', 'C'],
       'value1': range(6),
       'value2': np.random.randint(0, 100, 6) # 6 numeros aleatorios entre 1 - 100
})

# %%
df
# Out:
#   key  value1  value2
# 0   A       0      95
# 1   B       1      26
# 2   C       2      95
# 3   A       3      90
# 4   B       4      78
# 5   C       5      86

# %% [markdown]
# ## Aggregate

# %%
df.groupby('key').aggregate(['min', np.median, np.mean, max])# agrega a cada valor [min  median  mean max]
# Out:
#     value1                 value2
#        min median mean max    min median  mean max
# key
# A        0    1.5  1.5   3     90   92.5  92.5  95
# B        1    2.5  2.5   4     26   52.0  52.0  78
# C        2    3.5  3.5   5     86   90.5  90.5  95

# %%
df.groupby('key').aggregate({
    'value1': 'min',
    'value2': 'max'
}) # agrega a cada valor segun el dicionario
# Out:
#      value2  value1
# key
# A        48       0
# B        41       1
# C        52       2

# %% [markdown]
# ## Filter

# %%
df.groupby('key').std() # agrupa con la Desviacion estandar
# Out:
#       value1     value2
# key
# A    2.12132   3.535534
# B    2.12132  36.769553
# C    2.12132   6.363961

# %%
def filter_func(x):
    return x['value2'].std()>5

# %%
display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)")
# Out:
# 'df'
# "df.groupby('key').std()"
# "df.groupby('key').filter(filter_func)"

# %%
df.groupby('key').filter(filter_func)
# Out:
#   key  value1  value2
# 1   B       1      26
# 2   C       2      95
# 4   B       4      78
# 5   C       5      86

# %% [markdown]
# ## Transform

# %%
df.groupby('key').transform(lambda x: x - x.mean())# transforma el df con con su valor - media
# Out:
#    value1  value2
# 0    -1.5     2.5
# 1    -1.5   -26.0
# 2    -1.5     4.5
# 3     1.5    -2.5
# 4     1.5    26.0
# 5     1.5    -4.5

# %% [markdown]
# ## Apply
# (aplicar)

# %%
def norm_by_col2(x):
    x['value1'] /= x['value2'].sum() #x['value1'] = x['value1'] / x['value2'].sum()
    return x

# %%
df.groupby('key').apply(norm_by_col2)
# Out:
#   key    value1  value2
# 0   A  0.000000      95
# 1   B  0.009615      26
# 2   C  0.011050      95
# 3   A  0.016216      90
# 4   B  0.038462      78
# 5   C  0.027624      86

# %% [markdown]
# # División de datos por columnas

# %%
L = [0,1,0,1,2,0]# lista de valores segun la pocisio del key
print(df)
df.groupby(L).sum()
# Out:
#   key  value1  value2
# 0   A       0      95
# 1   B       1      26
# 2   C       2      95
# 3   A       3      90
# 4   B       4      78
# 5   C       5      86
#    value1  value2
# 0       7     276
# 1       4     116
# 2       4      78

# %%
df.groupby('key').sum()
# Out:
#      value1  value2
# key
# A         3     185
# B         5     104
# C         7     181

# %%
df.groupby(df['key']).sum()
# Out:
#      value1  value2
# key
# A         3     185
# B         5     104
# C         7     181

# %%
df2 = df.set_index('key')# indico que la columna key va hacer el indixe
df2
# Out:
#      value1  value2
# key
# A         0      95
# B         1      26
# C         2      95
# A         3      90
# B         4      78
# C         5      86

# %%
mapping = {
    'A': 'vowel',
    'B': 'consonant',
    'C': 'consonant'
} # dicionario de datos

# %%
df2.groupby(mapping).sum() # agrupa por los valores del Dicionario
# Out:
#            value1  value2
# consonant      12     285
# vowel           3     185

# %%
df2.groupby(str.lower).mean()# pasar a minusculas las key y saca la media
# Out:
#    value1  value2
# a     1.5    92.5
# b     2.5    52.0
# c     3.5    90.5

# %%
df2.groupby([str.lower, mapping]).mean() # combinacion de dos claves
# Out:
#              value1  value2
# a vowel         1.5    92.5
# b consonant     2.5    52.0
# c consonant     3.5    90.5

# %% [markdown]
# # Gráficos desde data frames y exportación

# %%
import numpy as np
years = [year for year in range(1900, 2020)]
deads = [(y + np.random.uniform(0,100) - 1850) for y in years]

# %%
df = pd.DataFrame({
    "year": years,
    "deads": deads
})

# %%
df.head()
# Out:
#    year       deads
# 0  1900  121.319416
# 1  1901   70.004820
# 2  1902  111.895348
# 3  1903   63.851974
# 4  1904  129.541040

# %%
df.plot( x="year", y = "deads", figsize = (10, 8))

# %%
my_plot = df.plot(kind = "scatter", x="year", y = "deads", figsize = (10, 8)) # creamos la variable de la imagen

# %%
my_fig = my_plot.get_figure() # asignamos la figura a una variable my_fig

# %%
my_fig.savefig("../../ejercicios/data_frame_plot2.png") # guardamos la imagen creada
